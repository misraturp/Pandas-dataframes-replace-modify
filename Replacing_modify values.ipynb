# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("NYC_Jobs.csv")
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                          NaN
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To
# 0            84252.0          84252.0
# 1            82884.0         116391.0
# 2           105000.0         125000.0
# 3            87203.0         131623.0
# 4            58449.0          67216.0

# %%
data.fillna('kitten')
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL           NYC HOUSING AUTHORITY
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
#      Posting Type                                 Job Category  \
# 0        External                                       Health
# 1        External                                       kitten
# 2        External                                Legal Affairs
# 3        External  Information Technology & Telecommunications
# 4        External    Constituent Services & Community Programs
# ...           ...                                          ...
# 3768     Internal                Technology, Data & Innovation
# 3769     Internal        Engineering, Architecture, & Planning
# 3770     Internal                Technology, Data & Innovation
# 3771     Internal           Finance, Accounting, & Procurement
# 3772     External                                Legal Affairs
#
#       Salary Range From  Salary Range To
# 0               84252.0          84252.0
# 1               82884.0         116391.0
# 2              105000.0         125000.0
# 3               87203.0         131623.0
# 4               58449.0          67216.0
# ...                 ...              ...
# 3768            85371.0         119883.0
# 3769            74650.0          85847.0
# 3770           100000.0         115000.0
# 3771            42288.0          59400.0
# 3772            62397.0          71757.0
#
# [3773 rows x 7 columns]

# %%
data.replace("NYC HOUSING AUTHORITY","NYC AUTHORITY FOR HOUSING")
data.replace("NYC HOUSING AUTHORITY",'NYC_Hous_A', inplace=True)
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
#      Posting Type                                 Job Category  \
# 0        External                                       Health
# 1        External                                          NaN
# 2        External                                Legal Affairs
# 3        External  Information Technology & Telecommunications
# 4        External    Constituent Services & Community Programs
# ...           ...                                          ...
# 3768     Internal                Technology, Data & Innovation
# 3769     Internal        Engineering, Architecture, & Planning
# 3770     Internal                Technology, Data & Innovation
# 3771     Internal           Finance, Accounting, & Procurement
# 3772     External                                Legal Affairs
#
#       Salary Range From  Salary Range To
# 0               84252.0          84252.0
# 1               82884.0         116391.0
# 2              105000.0         125000.0
# 3               87203.0         131623.0
# 4               58449.0          67216.0
# ...                 ...              ...
# 3768            85371.0         119883.0
# 3769            74650.0          85847.0
# 3770           100000.0         115000.0
# 3771            42288.0          59400.0
# 3772            62397.0          71757.0
#
# [3773 rows x 7 columns]

# %%
# Changes the value in the original dataframe

data.loc[data["Posting Type"] == "External", "Posting Type"] = 1
data.at[data["Posting Type"] == 1,'Civil Service Title']='CITA'
data.loc[0, "Posting Type"] = "Unknown" #works with at too

# %%
data.loc[0, "Posting Type"] = 12

# %%
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339                            CITA   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094                            CITA    NYC EMPLOYEES RETIREMENT SYS
# 2     520417                            CITA           NYC HOUSING AUTHORITY
# 3     233549                            CITA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256                            CITA         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739                            CITA         HUMAN RIGHTS COMMISSION
#
#      Posting Type                                 Job Category  \
# 0              12                                       Health
# 1               1                                          NaN
# 2               1                                Legal Affairs
# 3               1  Information Technology & Telecommunications
# 4               1    Constituent Services & Community Programs
# ...           ...                                          ...
# 3768     Internal                Technology, Data & Innovation
# 3769     Internal        Engineering, Architecture, & Planning
# 3770     Internal                Technology, Data & Innovation
# 3771     Internal           Finance, Accounting, & Procurement
# 3772            1                                Legal Affairs
#
#       Salary Range From  Salary Range To
# 0               84252.0          84252.0
# 1               82884.0         116391.0
# 2              105000.0         125000.0
# 3               87203.0         131623.0
# 4               58449.0          67216.0
# ...                 ...              ...
# 3768            85371.0         119883.0
# 3769            74650.0          85847.0
# 3770           100000.0         115000.0
# 3771            42288.0          59400.0
# 3772            62397.0          71757.0
#
# [3773 rows x 7 columns]

# %%
data["is_LegalAffairs"] = np.where(data["Job Category"] == "Legal Affairs", 1, 0)

# %%
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339                            CITA   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094                            CITA    NYC EMPLOYEES RETIREMENT SYS
# 2     520417                            CITA           NYC HOUSING AUTHORITY
# 3     233549                            CITA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256                            CITA         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739                            CITA         HUMAN RIGHTS COMMISSION
#
#      Posting Type                                 Job Category  \
# 0              12                                       Health
# 1               1                                          NaN
# 2               1                                Legal Affairs
# 3               1  Information Technology & Telecommunications
# 4               1    Constituent Services & Community Programs
# ...           ...                                          ...
# 3768     Internal                Technology, Data & Innovation
# 3769     Internal        Engineering, Architecture, & Planning
# 3770     Internal                Technology, Data & Innovation
# 3771     Internal           Finance, Accounting, & Procurement
# 3772            1                                Legal Affairs
#
#       Salary Range From  Salary Range To  is_LegalAffairs
# 0               84252.0          84252.0                0
# 1               82884.0         116391.0                0
# 2              105000.0         125000.0                1
# 3               87203.0         131623.0                0
# 4               58449.0          67216.0                0
# ...                 ...              ...              ...
# 3768            85371.0         119883.0                0
# 3769            74650.0          85847.0                0
# 3770           100000.0         115000.0                0
# 3771            42288.0          59400.0                0
# 3772            62397.0          71757.0                1
#
# [3773 rows x 8 columns]

# %%
data['Civil Service Title'].mask(data['Civil Service Title'] == 'SENIOR IT ARCHITECT', 0, inplace=False)
# Out:
# 0                                 CITA
# 1                                 CITA
# 2                                 CITA
# 3                                 CITA
# 4                                 CITA
#                      ...
# 3768    CERTIFIED IT ADMINISTRATOR (LA
# 3769     ASSOCIATE HOUSING DEVELOPMENT
# 3770                                 0
# 3771                         ECONOMIST
# 3772                              CITA
# Name: Civil Service Title, Length: 3773, dtype: object

# %%
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339                            CITA   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094                            CITA    NYC EMPLOYEES RETIREMENT SYS
# 2     520417                            CITA           NYC HOUSING AUTHORITY
# 3     233549                            CITA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256                            CITA         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739                            CITA         HUMAN RIGHTS COMMISSION
#
#      Posting Type                                 Job Category  \
# 0              12                                       Health
# 1               1                                          NaN
# 2               1                                Legal Affairs
# 3               1  Information Technology & Telecommunications
# 4               1    Constituent Services & Community Programs
# ...           ...                                          ...
# 3768     Internal                Technology, Data & Innovation
# 3769     Internal        Engineering, Architecture, & Planning
# 3770     Internal                Technology, Data & Innovation
# 3771     Internal           Finance, Accounting, & Procurement
# 3772            1                                Legal Affairs
#
#       Salary Range From  Salary Range To  is_LegalAffairs
# 0               84252.0          84252.0                0
# 1               82884.0         116391.0                0
# 2              105000.0         125000.0                1
# 3               87203.0         131623.0                0
# 4               58449.0          67216.0                0
# ...                 ...              ...              ...
# 3768            85371.0         119883.0                0
# 3769            74650.0          85847.0                0
# 3770           100000.0         115000.0                0
# 3771            42288.0          59400.0                0
# 3772            62397.0          71757.0                1
#
# [3773 rows x 8 columns]

# %%
def capitalize(text):
    return text.lower().capitalize()

data['Civil Service Title'].apply(capitalize)
# Out:
# 0                  Public health nurse
# 1              Cert it developer (app)
# 2             Executive agency counsel
# 3       Certified it administrator (la
# 4       Associate human rights special
#                      ...
# 3768    Certified it administrator (la
# 3769     Associate housing development
# 3770               Senior it architect
# 3771                         Economist
# 3772           Agency attorney interne
# Name: Civil Service Title, Length: 3773, dtype: object

# %%
def replace_values(text):
    if text == 'NYC EMPLOYEES RETIREMENT SYS':
        return 'Retirement SYS'
    elif text == 'HUMAN RIGHTS COMMISSION':
        return 'HRC'
    else:
        return text

data['Agency'] = data['Agency'].apply(replace_values)

# %%
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             Public health nurse   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         Cert it developer (app)                  Retirement SYS
# 2     520417        Executive agency counsel           NYC HOUSING AUTHORITY
# 3     233549  Certified it administrator (la                  Retirement SYS
# 4     510256  Associate human rights special                             HRC
# ...      ...                             ...                             ...
# 3768  457839  Certified it administrator (la                  Retirement SYS
# 3769  527141   Associate housing development  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             Senior it architect      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       Economist   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         Agency attorney interne                             HRC
#
#      Posting Type                                 Job Category  \
# 0        External                                       Health
# 1        External                                          NaN
# 2        External                                Legal Affairs
# 3        External  Information Technology & Telecommunications
# 4        External    Constituent Services & Community Programs
# ...           ...                                          ...
# 3768     Internal                Technology, Data & Innovation
# 3769     Internal        Engineering, Architecture, & Planning
# 3770     Internal                Technology, Data & Innovation
# 3771     Internal           Finance, Accounting, & Procurement
# 3772     External                                Legal Affairs
#
#       Salary Range From  Salary Range To
# 0               84252.0          84252.0
# 1               82884.0         116391.0
# 2              105000.0         125000.0
# 3               87203.0         131623.0
# 4               58449.0          67216.0
# ...                 ...              ...
# 3768            85371.0         119883.0
# 3769            74650.0          85847.0
# 3770           100000.0         115000.0
# 3771            42288.0          59400.0
# 3772            62397.0          71757.0
#
# [3773 rows x 7 columns]

# %%
data['Agency'].map({'NYC HOUSING AUTHORITY':'NYC_H_A'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-4e1305161877> in <module>
# ----> 1 data.map({'NYC HOUSING AUTHORITY':'NYC_H_A'})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
def add_year(value):
    return str(value) + '_2022'
    

data[['Job ID', 'Civil Service Title']] = data[['Job ID', 'Civil Service Title']].applymap(add_year)

# %%
data
# Out:
#            Job ID                  Civil Service Title  \
# 0     424339_2022                            CITA_2022
# 1     379094_2022                            CITA_2022
# 2     520417_2022                            CITA_2022
# 3     233549_2022                            CITA_2022
# 4     510256_2022                            CITA_2022
# ...           ...                                  ...
# 3768  457839_2022  CERTIFIED IT ADMINISTRATOR (LA_2022
# 3769  527141_2022   ASSOCIATE HOUSING DEVELOPMENT_2022
# 3770  509443_2022             SENIOR IT ARCHITECT_2022
# 3771  352367_2022                       ECONOMIST_2022
# 3772  478739_2022                            CITA_2022
#
#                               Agency Posting Type  \
# 0      DEPT OF HEALTH/MENTAL HYGIENE           12
# 1       NYC EMPLOYEES RETIREMENT SYS            1
# 2              NYC HOUSING AUTHORITY            1
# 3       NYC EMPLOYEES RETIREMENT SYS            1
# 4            HUMAN RIGHTS COMMISSION            1
# ...                              ...          ...
# 3768    NYC EMPLOYEES RETIREMENT SYS     Internal
# 3769  HOUSING PRESERVATION & DVLPMNT     Internal
# 3770      FINANCIAL INFO SVCS AGENCY     Internal
# 3771   DEPT OF HEALTH/MENTAL HYGIENE     Internal
# 3772         HUMAN RIGHTS COMMISSION            1
#
#                                      Job Category  Salary Range From  \
# 0                                          Health            84252.0
# 1                                             NaN            82884.0
# 2                                   Legal Affairs           105000.0
# 3     Information Technology & Telecommunications            87203.0
# 4       Constituent Services & Community Programs            58449.0
# ...                                           ...                ...
# 3768                Technology, Data & Innovation            85371.0
# 3769        Engineering, Architecture, & Planning            74650.0
# 3770                Technology, Data & Innovation           100000.0
# 3771           Finance, Accounting, & Procurement            42288.0
# 3772                                Legal Affairs            62397.0
#
#       Salary Range To  is_LegalAffairs
# 0             84252.0                0
# 1            116391.0                0
# 2            125000.0                1
# 3            131623.0                0
# 4             67216.0                0
# ...               ...              ...
# 3768         119883.0                0
# 3769          85847.0                0
# 3770         115000.0                0
# 3771          59400.0                0
# 3772          71757.0                1
#
# [3773 rows x 8 columns]

# %%
data['Salary range'] = pd.cut(data['Salary Range From'], 3)
data
# Out:
#            Job ID                  Civil Service Title  \
# 0     424339_2022                            CITA_2022
# 1     379094_2022                            CITA_2022
# 2     520417_2022                            CITA_2022
# 3     233549_2022                            CITA_2022
# 4     510256_2022                            CITA_2022
# ...           ...                                  ...
# 3768  457839_2022  CERTIFIED IT ADMINISTRATOR (LA_2022
# 3769  527141_2022   ASSOCIATE HOUSING DEVELOPMENT_2022
# 3770  509443_2022             SENIOR IT ARCHITECT_2022
# 3771  352367_2022                       ECONOMIST_2022
# 3772  478739_2022                            CITA_2022
#
#                               Agency Posting Type  \
# 0      DEPT OF HEALTH/MENTAL HYGIENE           12
# 1       NYC EMPLOYEES RETIREMENT SYS            1
# 2              NYC HOUSING AUTHORITY            1
# 3       NYC EMPLOYEES RETIREMENT SYS            1
# 4            HUMAN RIGHTS COMMISSION            1
# ...                              ...          ...
# 3768    NYC EMPLOYEES RETIREMENT SYS     Internal
# 3769  HOUSING PRESERVATION & DVLPMNT     Internal
# 3770      FINANCIAL INFO SVCS AGENCY     Internal
# 3771   DEPT OF HEALTH/MENTAL HYGIENE     Internal
# 3772         HUMAN RIGHTS COMMISSION            1
#
#                                      Job Category  Salary Range From  \
# 0                                          Health            84252.0
# 1                                             NaN            82884.0
# 2                                   Legal Affairs           105000.0
# 3     Information Technology & Telecommunications            87203.0
# 4       Constituent Services & Community Programs            58449.0
# ...                                           ...                ...
# 3768                Technology, Data & Innovation            85371.0
# 3769        Engineering, Architecture, & Planning            74650.0
# 3770                Technology, Data & Innovation           100000.0
# 3771           Finance, Accounting, & Procurement            42288.0
# 3772                                Legal Affairs            62397.0
#
#       Salary Range To  is_LegalAffairs             Salary range
# 0             84252.0                0  (83333.333, 166666.667]
# 1            116391.0                0      (-250.0, 83333.333]
# 2            125000.0                1  (83333.333, 166666.667]
# 3            131623.0                0  (83333.333, 166666.667]
# 4             67216.0                0      (-250.0, 83333.333]
# ...               ...              ...                      ...
# 3768         119883.0                0  (83333.333, 166666.667]
# 3769          85847.0                0      (-250.0, 83333.333]
# 3770         115000.0                0  (83333.333, 166666.667]
# 3771          59400.0                0      (-250.0, 83333.333]
# 3772          71757.0                1      (-250.0, 83333.333]
#
# [3773 rows x 9 columns]

# %%
df = pd.DataFrame({'A': [1, 2, 3],
                   'B': [400, 500, 600]})
new_df = pd.DataFrame({'B': [4, 5, 6],
                       'C': [7, 8, 9]})

# %%
df
# Out:
#    A    B
# 0  1  400
# 1  2  500
# 2  3  600

# %%
new_df
# Out:
#    B  C
# 0  4  7
# 1  5  8
# 2  6  9

# %%
df.update(new_df)
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
